# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
fid = drive.ListFile({'q':"title='train.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('train.zip')
f.Upload()

# %%
fid = drive.ListFile({'q':"title='test1.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('test1.zip')
f.Upload()

# %%
fid = drive.ListFile({'q':"title='validation.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('validation.zip')
f.Upload()

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#    creating: train/
#    creating: train/westminster_abbey/
#   inflating: train/westminster_abbey/3091216052.jpg
#   inflating: train/westminster_abbey/999231590.jpg
#   inflating: train/westminster_abbey/3092954478.jpg
#   inflating: train/westminster_abbey/2376161501.jpg
#   inflating: train/westminster_abbey/3674041217.jpg
#   inflating: train/westminster_abbey/4604696125.jpg
#   inflating: train/westminster_abbey/377596262.jpg
#   inflating: train/westminster_abbey/436224383.jpg
#   inflating: train/westminster_abbey/2343682178.jpg
#   inflating: train/westminster_abbey/3056926829.jpg
#   inflating: train/westminster_abbey/1335242127.jpg
#   inflating: train/westminster_abbey/5592749733.jpg
#   inflating: train/westminster_abbey/4041572288.jpg
#   inflating: train/westminster_abbey/5481501132.jpg
#   inflating: train/westminster_abbey/260779135.jpg
#   inflating: train/westminster_abbey/771866711.jpg
#   inflating: train/westminster_abbey/5313749544.jpg
# ...

# %%
# !unzip validation.zip
# Out:
# Archive:  validation.zip
#    creating: validation/
#    creating: validation/casa_loma/
#  extracting: validation/casa_loma/1007041737.jpg
#  extracting: validation/casa_loma/1008016284.jpg
#   inflating: validation/casa_loma/1314212563.jpg
#   inflating: validation/casa_loma/1315106984.jpg
#   inflating: validation/casa_loma/1326036828.jpg
#   inflating: validation/casa_loma/1537188059.jpg
#  extracting: validation/casa_loma/1537188463.jpg
#   inflating: validation/casa_loma/1663118285.jpg
#   inflating: validation/casa_loma/1680773510.jpg
#   inflating: validation/casa_loma/173005629.jpg
#   inflating: validation/casa_loma/19407007.jpg
#   inflating: validation/casa_loma/1947494139.jpg
#   inflating: validation/casa_loma/2196276817.jpg
#   inflating: validation/casa_loma/2381367033.jpg
#  extracting: validation/casa_loma/243024227.jpg
#   inflating: validation/casa_loma/2441576441.jpg
#  extracting: validation/casa_loma/2568277959.jpg
# ...

# %%
# !unzip test1.zip
# Out:
# Archive:  test1.zip
#    creating: test1/
#    creating: test1/casa_loma/
#  extracting: test1/casa_loma/1007041747.jpg
#  extracting: test1/casa_loma/1029926195.jpg
#   inflating: test1/casa_loma/1029930963.jpg
#  extracting: test1/casa_loma/105459683.jpg
#  extracting: test1/casa_loma/1121606274.jpg
#   inflating: test1/casa_loma/1121606786.jpg
#   inflating: test1/casa_loma/115622209.jpg
#   inflating: test1/casa_loma/115622394.jpg
#   inflating: test1/casa_loma/115622635.jpg
#   inflating: test1/casa_loma/117018647.jpg
#   inflating: test1/casa_loma/1314197787.jpg
#   inflating: test1/casa_loma/1315171402.jpg
#   inflating: test1/casa_loma/1404553489.jpg
#   inflating: test1/casa_loma/144349167.jpg
#   inflating: test1/casa_loma/145142805.jpg
#   inflating: test1/casa_loma/1537187511.jpg
#  extracting: test1/casa_loma/1537188341.jpg
#   inflating: test1/casa_loma/1537188981.jpg
#   inflating: test1/casa_loma/1538051784.jpg
#   inflating: test1/casa_loma/1663030087.jpg
# ...

# %%
folder_id='1RyLZI58RPiGO1NVKb72YHHJzOwFmAoZL'
lister = drive.ListFile({'q': "'%s' in parents" % folder_id}).GetList()
for item in lister:
   # item.GetContentFile('title')
    item.Upload()

# %%
# !ls
# Out:
# adc.json     test1	title  train.zip   validation.zip
# sample_data  test1.zip	train  validation
